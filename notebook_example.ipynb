# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Example of using numpy, pandas, and matplotlib
#
# ## Creating dataframe

# %%
df = pd.DataFrame(columns=['A', 'B', 'C'])

for col in df.columns:
    df[col] = np.random.lognormal(size=1000)

df['D'] = df['A'] * df['B']

df.head()
# Out:
#           A         B         C          D
# 0  0.700977  1.184069  0.262779   0.830005
# 1  1.487190  1.000159  0.505140   1.487427
# 2  1.410349  3.133139  0.235553   4.418820
# 3  0.162066  1.835631  1.274168   0.297494
# 4  2.859392  9.784895  1.069130  27.978849

# %% [markdown]
# ## Taking the log

# %%
df_mod = np.log(df)

df_mod.head()
# Out:
#           A         B         C         D
# 0 -0.355281  0.168957 -1.336442 -0.186323
# 1  0.396889  0.000159 -0.682920  0.397047
# 2  0.343837  1.142036 -1.445819  1.485873
# 3 -1.819749  0.607388  0.242293 -1.212361
# 4  1.050609  2.280840  0.066845  3.331449

# %% [markdown]
# ## Plotting the results

# %%
plt.scatter(df_mod['A'], df_mod['D'])
plt.xlabel('A')
plt.ylabel('D')
plt.title('Example Scatter Plot')
plt.show()

# %%
plt.hist(df_mod['D'])
plt.show()

# %%
from sklearn.linear_model import LinearRegression

line = LinearRegression()

line.fit(df_mod[['A', 'C']], df_mod['D'])

line.score(df_mod[['A', 'C']], df_mod['D'])
# Out:
# 0.4944742595446535

# %%
plt.scatter(df_mod['A'], df_mod['C'], c=df_mod['D'])
plt.show()
